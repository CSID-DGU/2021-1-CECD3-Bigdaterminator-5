# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import sys

import numpy as np

np.set_printoptions(threshold=sys.maxsize)

list = ['이준석 태영호가 자본주의 더 잘 알아 준슥게이 기준 피케티 뿅뿅행준슥이 보면민주당 문재인 싫어하는건 이해하는데표현이 과격하고무지성으로 비난해서 문제 아무리 그래도 태영호가 민주당 보다 낫다고  빨갱이 새끼 애지네 쟤가 그래도 디씨같은 커뮤를 오래해서 그쪽 성향에 맞는 언행을 하는거임우리 준슥게이는 마이클 센델더러도 내가 하바드 다녀봐서 아는데 우리 학교에선 걍 병신임 이라고 주장한 전적이 있다한국에서 하버드 학교이미지 만든 등공신그냥 단순히 저급한 인간인 줄로만 알았는데 이제보니 종북 빨갱이잖어  사상이 의심된다럭키 간결우리 준슥게이는 마이클 센델더러도 내가 하바드 다녀봐서 아는데 우리 학교에선 걍 병신임 이라고 주장한 전적이 있다준슦이는 자기 힘으로 이뤄낸 게 하버드 컴공 학사랑 서울시 택시기사밖에 없으면서 왜 나대는 걸까정치 입문도 사실상  후광 업고 한 거잖아센델 강의 하버드에서도 인기강의중 하나 아님컴공 학부생이 철학과 건물에 드나들어 본 적이나 있었을까걍 아가리에서 나오는 대로 씨부리는 것밖에 못 함 쟤는이래서 이과라도 인문학적 소양 안 갖추면 걍 이라니까한국에서 하버드 학교이미지 만든 등공신쟤가 그래도 디씨같은 커뮤를 오래해서 그쪽 성향에 맞는 언행을 하는거임럭키 간결생각 외로 저런 헛소릴 하는 놈들이 많단게 유우머다 그냥 단순히 저급한 인간인 줄로만 알았는데 이제보니 종북 빨갱이잖어  사상이 의심된다내가 얘를 보면서 좋은 대학 나와도 의외로 일수도 있다라는 생각을 가짐오구구 준스기 이젠 태영호에게 시간 듣고 자본주의를 깨쳤어요탈북한 이유가 돈때문이면 충분히 가능사기전과범이 자본주의는 제일 잘 알지일베버러지맞춤이라는 소리네 그게 바로 일베버러지지나이 많지도 않은 놈이 민주당  주체사상 이딴 개소리나 하고 있으니 진짜 문제임그럼 태영호 억 재산 출처부터 캐자윾머베프 수준 리준석']
tfidfv = TfidfVectorizer().fit(list)
print(tfidfv.transform(list).toarray())
print(tfidfv.vocabulary_)
# Out:
# [[0.06085806 0.06085806 0.06085806 0.06085806 0.06085806 0.06085806
#   0.06085806 0.06085806 0.06085806 0.06085806 0.06085806 0.06085806
#   0.06085806 0.06085806 0.18257419 0.12171612 0.06085806 0.06085806
#   0.06085806 0.06085806 0.06085806 0.06085806 0.12171612 0.06085806
#   0.06085806 0.12171612 0.12171612 0.06085806 0.06085806 0.06085806
#   0.06085806 0.06085806 0.06085806 0.06085806 0.12171612 0.06085806
#   0.12171612 0.12171612 0.06085806 0.06085806 0.12171612 0.06085806
#   0.06085806 0.06085806 0.12171612 0.06085806 0.12171612 0.06085806
#   0.06085806 0.06085806 0.06085806 0.06085806 0.12171612 0.06085806
#   0.12171612 0.06085806 0.06085806 0.06085806 0.06085806 0.12171612
#   0.12171612 0.06085806 0.06085806 0.06085806 0.06085806 0.06085806
#   0.06085806 0.06085806 0.12171612 0.06085806 0.06085806 0.06085806
#   0.06085806 0.12171612 0.06085806 0.06085806 0.06085806 0.12171612
#   0.06085806 0.06085806 0.12171612 0.06085806 0.12171612 0.06085806
# ...
