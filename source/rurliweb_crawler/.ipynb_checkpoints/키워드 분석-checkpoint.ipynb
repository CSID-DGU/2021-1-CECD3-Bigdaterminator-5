# %%
import json
import csv
import pandas as pd
from konlpy.tag import Komoran
from konlpy.corpus import kolaw
from konlpy.tag import Okt
#import nltk
#from nltk import Text
from collections import Counter

data = pd.read_csv('루리웹.csv', encoding="euc-kr", engine = 'python')
data.values
values = "".join(str(i) for i in data.values)

komoran = Komoran() 

total_morphs = komoran.morphs(values)

print("전체 형태소 개수: ")
print(len(total_morphs))

nouns = komoran.nouns(values)
print("전체 명사 개수: ")
print(len(nouns))

nouns = [noun for noun in nouns if len(noun) >= 2]

bool_words = ['이랑', '사람', '생각', '정도', '얼굴', '섹스', '문제', '새끼', '이상', '사실',
              '요즘', '댓글', '시간', '루리웹', '아아', '게시판','이미지', '이용', '지랄', '병신' ,'친구', '모양']

for word in nouns:
    if word in bool_words:
        while word in nouns: 
            nouns.remove(word)

word_cnt = Counter(nouns).most_common()
total_df = pd.DataFrame(word_cnt, columns = ['단어', '빈도수'])
total_df.head(10)
# Out:
# 전체 형태소 개수:
# 3191
# 전체 명사 개수:
# 1168
#     단어  빈도수
# 0  문재인   13
# 1   충성    8
# 2   게시    8
# 3   일본    8
# 4   신청    7
# 5   정치    6
# 6   소리    6
# 7   모집    5
# 8  게시물    5
# 9   감사    5
