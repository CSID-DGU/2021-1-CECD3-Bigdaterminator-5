# %%
import requests
import time
import os
import sys
import re
import io
import json
import csv
import openpyxl
import pandas as pd
import numpy as np
import kss
import ast
from pykospacing import spacing
from konlpy.tag import Komoran
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-40bffe37771d> in <module>
#      10 import pandas as pd
#      11 import numpy as np
# ---> 12 import kss
#      13 import ast
#      14 from pykospacing import spacing
#
# ModuleNotFoundError: No module named 'kss'

# %%
# !pip install kss
# Out:
# Collecting kss
#   Downloading kss-2.5.1-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 1.7 MB/s eta 0:00:011
# Installing collected packages: kss
# Successfully installed kss-2.5.1

# %%
#각 키워드에 해당하는 내용 정리
#예시: ['결혼', '남자', '남편', '본인', '부모', '시간', '엄마', '여자', '자기', '친구']
from IPython.core.display import display, HTML
from konlpy.tag import Okt

#키워드에 해당하는 제목, 본문, 댓글 출력, 추후 iteration 돌며 10가지 모두 할 것
key = '자기'

final = pd.DataFrame(columns = ['contents'])

f = pd.read_csv('natepann.csv')

#키워드 본문, 제목, 댓글 돌며 확인
is_key = f['본문'].str.contains(key, na=False) | f['제목'].str.contains(key, na=False) | f['댓글'].str.contains(key, na=False)


f_key = f[is_key]
f_key = f_key.reset_index()
f_key
# Out:
#     index                            제목  \
# 0       0              너네엄 마라고 하는 시 어머니
# 1       1            임신에 대한 친정과 시댁의 온도차
# 2       2         예비 신랑 탈모 때문에 너무 고민입니다
# 3       4           한 회사에서 꾸준히 오래 다니는 법
# 4       5         회계사 시험 붙더니 헤어지자는 남자친구
# 5       6  얘들아 남자들 생떼 쓰는 것 좀 막아보자 청원 부탁
# 6       7        엄마가 필리핀 사람이라 비혼주의가 됐어요
# 7       9          시댁 문제로 남편과 심각하게 싸웠어요
# 8      12               예비 시동생 과거 파혼 결혼
# 9      14    년 계약한 세입자가 년 더 살겠다는데 가능한가요
# 10     15                       힘든 결혼생활
# 11     16          조리원은 자분한 사람만 가는 곳인가요
# 12     17        신은 견딜 수 있는 만큼의 시련만 준 대
# 13     19           여친 때문에 유학 안 가겠다는 아들
# 14     21             남자랑 여행 가면 무조건 그거해
# 15     23   여자 술집에서 폭행 시비가 걸렸습니다 도와 주세요
# 16     24          대기업 인테리어 시공 엉망진창 서비스
# 17     26           이혼 후 재결합 해보신분 있으실까요
# 18     28               이 여 자랑 결혼해도 될까요
# 19     29            부부싸움 후 남편이 물건 부셨네요
# 20     30                          돌아보니
# 21     36               시동생과 단 둘이 두는 남편
# 22     40                     시누와의 비교질에
# 23     42                년 사귄 남친과 헤어졌어요
# 24     45                끼리끼리 못 어울리는 사람
# 25     46                    시댁에 대해 솔직히
# 26     49  정신과 치료를 오랫동안 받고 있는 남자친구 결혼하면
# 27     53       주문한 커피를 떨어뜨렸는데 다시 안 주더라
# 28     68       상사의 폭언에 말 대답했는데 잘못한 걸까요
# 29     71           유치원 친구의 놀림 어찌해야 하나요
# 30     75                  결혼 스탑 해야 할까요
# 31     76           애 기울면 나한테 화부터 내고 본다
# 32     79                   회피 고집 후회 없는
# 33     80   다른 집들도 이러나요 너무 속상하고 마음이 아파요
# 34     88              남친누나의 얼평 및 신원 확인
# 35     90                   자기가 깨우칠 때까지
# 15  폭행치사음 그래요 변호사랑 경찰이랑 얘기 된 것 같은데 여기서 사람들이 뭘 어떻게 ...
# 16                         헐 이게 무슨 일이건 공론화 해야 할 거 같네요
# 17  자기 인생 꼬는 사람들 심리가 이렇구나 써 논 글 다시 읽어봐요 얼마나 힘들었음 이...
# 18  글쓴이 병이 있는데 치료 조차 안 하는 그런 여자와 결혼 하는 거 아님 가풍 있고 ...
# 19  나이가 똑같으면 반 반 한다고 하세요 어린 친구들이 오는 곳이라 댓글 수준이 중졸 ...
# 20  맞는 말 우리가 그걸 알아야 하냐 아닐 텐데 요 맞는 말이 다진 짱이 거 위에 올려...
# 21  이 복동생이라고 굳이 왜 썼엌 다시 쓰자 이 거 정말 주작인 거 아니면 시동생 독립...
# 22  싸움거는 지 엄마한테는 찍 소리 안 하고 밥 시켜먹는다니까 또 또 지 아내한테만 지...
# 23  이제 꽃 피울 나이네요저도 에 헤어졌는데 이제는 아쉽기보다는 지금이라도 헤어져서 다...
# 24  안 물안 궁 그 집 나간 존 못 마누라 아지매는 아직 컴백홈 안함가 정파탄 성매매 ...
# 25  어느 쪽 부 모든 부당한 대우와 요구 이유 없는 폭력적 언사로 내 삶을 혼란스럽게 ...
# 26  정 실질환 유전되는 건 아시죠주작이 아니라면 쓰니 가족 그리고 주변에 상담해 줄 수...
# 27  저런 년도 페미일까 이거 보니까 잊고 지내던 기 억이 떠오름 예전에 핫플 카페 갔는...
# 28  지가 후임한테 똑같이 해서 찔리는 거 있나 봐요 쓴 이 잘했어요 친구 같지도 않은 ...
# 29  유치원 담임샘한테 말해서 아이들 지도 바란다고 하세요 유치원생이면 그래도 교육과 훈...
# 30  개월 만남이라 월 상환 년은 꼼짝없이 해야 한다는 소리인데 아이라도 생기거나 사 정...
# 31  애 앞에서 애말만 듣고 아빠를 야단친다 애는 엄마가 일 등 아빠는 나보다 아래 사람...
# 32  너 혼자 변함없이 좋아하는 거 아니냐 주 작질하냐 푸핫 사람이라면 오죠 다만 겉으로...
# 33  정말 많이 외롭고 힘들고 버거울 거 같아 요 읽는 동안 마음이 많이 아프네 요저는 ...
# 34  지가 맘에 안 들면 어쩔껀 데 얼평하구 자 빠졌네싹 수가 노랗다 그리고 니 남친 대...
# 35  주작질하냐 잃어봐야 깨닫는 게 대다수의 남자입니다 있을 때 깨닫기가 힘들어요 아마 ...
# 36  박사 가 서 거기서 조건이 비슷한 사람 만나세요 나이도 어리고 아직 정착도 안된 상...
# 37  저도 개월이라 공감되요 전 임신준비하면서 십키로 찐 상태로 임신한 거라 더 예민 안...
# 38        헐애써 쎈척 하는 찌질이 컨셉인가 후려치기 하면 원래 없었던 자존감이 올라가나
# 39  전남 친은 이글 보고 신고 했으면 난 이런 글이 이 해안되는 게 헤어졌으면 끝 아닌...

# %%
final_key = pd.DataFrame(columns = ['tokenized'])
komoran = Komoran()

for i in range(len(f_key)):
    try:
        st = f_key.loc[i, '제목']
        final_key.loc[i, 'tokenized'] = str(st)
        ct = f_key.loc[i, '본문']
        final_key.loc[i, 'tokenized'] += str(ct)
        
        cm = f_key.loc[i, '댓글']
        #str Concatenation 문제 발생시 주석처리한 부분처럼 str() 처리하면 해결 가능
        #final_key.loc[i, 'tokenized'] += cm
        final_key.loc[i, 'tokenized'] += str(cm)
        
    except KeyError:
        print("error")

keyword_content = pd.DataFrame(columns = ['content','positive', 'negative', 'neutral'])


for i in range(len(final_key)):
    try:
        fc = final_key.loc[i, 'tokenized']#.replace(" ", "")
        fc = spacing(fc)
        #fc = str(komoran.morphs(fc))
        
        if i == 0:
            keyword_content.loc[0,'content'] = fc
        else:
            keyword_content.loc[0,'content'] += fc
        
    except KeyError:
        print("error")

keyword_content
# Out:
#                                              content positive negative neutral
# 0  너네엄 마라고 하는 시 어머니 어느 순간부터 시 어머니가 친 정 엄마를 지칭해서 말...      NaN      NaN     NaN

# %%
# 감성사전에서 감성분석
f = open('SentiWord_Dict.txt', 'r', -1, 'utf-8')
lines = f.readlines()

score_dict = []

for line in lines:
    line_splited = line.split()
    score = int(line_splited[-1])
    word = ''
    for frac in line_splited[:-1]:
        word = word + ' ' + frac
    
    word = word[1:]
    score_dict.append([word, score])

# %%
#keys = []

keyword_content['positive'] = 0
keyword_content['negative'] = 0
keyword_content['neutral'] = 0

#komoran = Komoran()
#keys = spacing(keyword_content.loc[0, 'content'])
#keys = = str(komoran.nouns(keys)

#keyword_content.loc[0, 'content'] = spacing(keyword_content.loc[0, 'content'])
keyword_content.loc[0, 'content'] = str(komoran.nouns(keyword_content.loc[0, 'content']))


stopwords = ['하다', '없다', '있다', '되다', '아니다', '같다', '이다', '않다', '그렇다', 
             '이렇다', '싶다', '다', '것', '그', '이', '거', '니다']


pos_list = ast.literal_eval(keyword_content.loc[0, 'content'])
    
final = []
    
for j in range(len(pos_list)):
    if pos_list[j] not in stopwords:
        final.append(pos_list[j])
    
keyword_content.loc[0, 'content'] = str(final)
#keys = str(final)

# %%
keyword_content.insert(0, "Keyword", key)

# %%
#keyword_content.head()

# %%
#tokens.append(keyword_content.loc[0, 'content'])
#tokens.extend(keys)

tokens = ast.literal_eval(keyword_content.loc[0, 'content'])

try:
    for token in tokens:
        for dict_word in score_dict:
            if dict_word[0] == token:
                if dict_word[1] > 0:
                    keyword_content.loc[0, 'positive'] += dict_word[1]
                elif dict_word[1] < 0:
                    keyword_content.loc[0, 'negative'] += dict_word[1]
                else:
                    keyword_content.loc[0, 'neutral'] += 1 #중립어는 개수 세기    
except KeyError:
    print("error")

# %%
keyword_content[keyword_content.columns.difference(['content'])]
# Out:
#   Keyword  negative  neutral  positive
# 0      자기      -633       15       360

# %%
#% 시각화
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import font_manager, rc
import platform

#한글 꺠짐 처리
if platform.system() == 'Windows':
# 윈도우인 경우
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:    
# Mac 인 경우
    rc('font', family='AppleGothic')
    
matplotlib.rcParams['axes.unicode_minus'] = False
pos = keyword_content.loc[0, 'positive']
neg = str(keyword_content.loc[0, 'negative']).replace("-", "")
neu = keyword_content.loc[0, 'neutral']

size = [pos, neg, neu]

label = ['Positive','Negative','Neutral']

plt.axis('equal')
plt.pie(x=size, labels=label, autopct='%.2f%%')

plt.title("키워드 : " + key)
plt.legend(loc="upper right")
plt.show()
