# %%
import pandas as pd

df = pd.read_csv('natepann_Morphs.csv')
df.to_csv('natepann_Morphs.txt', sep = '\t', index = False)

# %%
def fileopen(data):
    
    #파일 불러오기 
    with open(data, 'r', encoding='utf-8') as file:
        
        text = file.read()
        
        splitdata = text.split()
        
        #리스트의 중첩된 부분 삭제하기 
        splitdata = list(dict.fromkeys(splitdata))
 
    return splitdata
 
 
if __name__ == '__main__':
 
    #파일1번 불러오기
    NewList1 = fileopen('natepann.txt')
    
    #파일2번 불러오기
    NewList2 = fileopen('SentiWord_Dict.txt')
    
    #파일3번 불러오기
    NewList3 = fileopen('sejong.txt')
    
    # 파일 1번에는 포함되고 파일2번에는 포함되지 않은 맴버 출력 
    #print(list(set(NewList1)-set(NewList2)))

    wordlist = list((set(NewList1)-set(NewList2))-set(NewList3))
    
    print(wordlist)
# Out:
# ['완화', '보여줬는데', '호들갑', '힘들어서', '취향이', '안된다고', '대처했던', '시켰는지정말', '집까지', '고칠', '부분은', '간다제가', '내어서', '거죠자꾸', '큰거', '안된다잉이렇게', '거리고', '소요', '근년간은', '놀아주기도', '신기한건', '구입하길', '자정에', '아기인데', '등등들기름김치찜', '지저분', '허리랑', '좋았냐', '된다면', '한정되어', '선물해줄', '팀나', '알거같기도레드벨벳', '찰떡인', '중요햇기', '그런건지너무', '힘든거', '낸다고', '응원', '걔는', '개념없네', '잘살거나', '배격하는', '바랄게우리', '대세요하며', '학창시절', '때부터', '등을', '김종현', '못했네요진짜', '멧갈라', '정시공부하고', '끝내기', '않나요진짜', '모르는척', '안되겠다고계속그래요그날', '인형에', '바꿨을거에요또', '가족을', '엄마니까', '쳐도소민', '억울하지도안하구요시부모님재산이', '숙취', '버블을', '안한다고', '기사가', '년가깝게', '것이다월급이', '갖게', '관리비랑', '참고이런', '여자입니다', '아시련지너희둘만', '관리하는게', '주세요', '괜찮아지겠지', '명사는데요', '양측의', '이러는거', '저희집으로', '아파트를알아보는', '옷사러', '싸웠습니다남자친구는', '챙기도록', '나왔는데공명', '민현', '못벌어', '합의했다는', '초대', '묶기의', '삼박자', '생각합니다결론적으로', '체격이', '아는데우리는', '퀄리티든', '이유를', '인지한후에는', '미안해요', '아이들에', '투샷', '지민설현', '못받고', '이식해주면', '청량청순아련몽환', '알게됐어가스라이팅인거', '원더걸스', '별일이', '마니나고', '말해야하니', '티내기', '에리얼은', '하겠답니다', '치는거같음', '몇시간동안', '맘정리하고', '얘기하냐', '까는데', '짱진짜', '꺼졌습니다', '적고가', '넘습니다입지도', '야는', '식사함결혼', '담배', '보자기', '업체들이', '학폭글', '벽', '일하구', '커뮤서', '통과', '아주버님', '해봅니다', '한국관광공사', '없는거', '걘', '걸려온', '남자만', '운영중이에요', '들으니깐', '컷이', '잘함', '레깅스에', '사라집니다저렇게', '준비하면서', '에다가본인', '화장실서', '아니라꽤나', '본가가면', '나올', '해두신', '파트만', '친구거든요', '식도미남', '주식넣고', '격리도', '여쭤봅니다', '순둥순둥한', '아기키우시는', '성인인데', '한번이', '두분이서', '하는것도', '안그러고', '했어요휴', '초아도', '감옥같은곳에', '내게', '기존커플', '하는거지', '아파트인지가', '다녀볼라구발치', '잘못한상황이었나요', '톡방', '모르겠넹', '해결해보려구요되도록', '전달했다', '아무도없는', '있었어요그런데', '겉으로', '싫어한다라고', '의견대립에서', '최고순위', '많이했고제가', '볼거', '찍는', '통탄', '보정본', '줄꺼에요그냥은', '입는거나', '이후임', '현관에서', '공감됨', '그사람과', '둘까', '토해냈다또한', '좋음글은', '첫인상', '수준임이정도면', '최근들어서는결혼도', '최예나', '함께할', '리정이랑', '엄마', '사람이다보니', '지마음을', '오버로', '욕하는', '마음아픈', '성묘도', '나도우리가', '셋다', '싫었지너네가', '갚아야해서', '웃어대고', '제욕이군요', '연령대로', '얼마전', '호칭이', '갠적으로', '맘에드는거', '싶네요돌전', '욕쳐먹었지만다시', '이혼하기로', '연락했더니', '메뉴를', '보존해', '오프', '신인돌들', '그럴수있죠', '요양', '알아두셈안내', '반반하자는거', '맡겨서', '이야기하자', '푼도못', '얘기하길래', '몰아있는데', '여자몸에', '자야한다', '먹으라는', '해명해야되는거아닌가', '언급하길래', '했대요이혼은', '저녁이나', '기혼이', '지우겠습니다댓글은', '내버려둬', '우리엄마는', '대출도', '사진에', '웃기게하면서', '붙어도', '어디서했냐', '짙은', '사람이었다면결혼', '모자른', '아니죠', '불황을', '현관만', '커플', '글조차도', '배신하는거고', '물어뜯기고', '제우스의', '힘들어', '동생그러니까', '좋아해챕터는', '음원', '보입시다', '아동', '김장마다', '입주청소', '가야하겠죠근데', '잘못은', '이유지', '피씨버전도', '안하길래', '양아치', '박수칠때', '결론이', '입을까', '헤어지곤', '근황', '살았죠능렸있는', '학교는', '만들었음', '나날만', '수요층이', '저지쇼로', '하더라고요', '차지하지만', '말도안되게', '있어요일주일', '이맘', '이해못해주는', '된거같아요', '갖기로', '말씀이세요시아까', '표현도', '중반에', '합격', '서울로', '아까운게', '몰랐대요', '받아쓰시라고', '대기업다니다가', '보고싶다', '붙음뷰티', '이사간다는', '바보였을까요하하하하하이건', '명이래블아필', '그는', '것에', '출산을', '살려낼', '오네요학창시절에도', '내려오겠다', '부담스럽네요', '앞에선', '분위기잠시쎄했으나', '오디션', '필요이상으로', '확인하니', '세트랑', '하려', '미안했다', '인사', '오며가며', '돼지같다면서', '키우냐', '친분을', '무엇', '과정내내', '비누꽃을', '격투기', '뭐라한다아기가', '접종자는', '시미즈프라우드먼', '넘어갔으니까공식', '백이상이었지만', '속터져서', '미쳐버렸나봐', '지르는걸', '분들정말', '태용이랑', '안할꺼면', '면목이', '물질적', '안하는중이시고', '생각도', '돌리기', '숙소에', '결정했는지는', '플레이', '아파트가', '불리는', '청순청량', '누구냐고', '찾느라고', '있겠구나', '퍼붓기도', '글만', '너무아픈데', '컨셉이라니', '옮기고', '들어주지', '육아휴직', '편이라고', '닮았다', '많을듯', '지들이', '힘든지', '없으니까요여러', '기존', '천번이해가고', '돈받지', '비유', '놈들도', '나눠줘야한다면', '미칠거', '지하철', '가져가서', '않았다는', '한명씩은', '콘서트에서', '안옴', '어떤간식을', '삼성', '왜소해보이는거지', '미치겠는건', '안되는건지', '침대', '이러시더라구요전화드려서', '병원비하고', '개콘이', '했으니', '되었고저에게', '천변쪽을', '견적', '하셨습니다', '뭐가문제냐고', '많았나', '진학', '싸가지없다는', '트롤취급하며', '밥먹어', '국어랑', '문제없습니다경제적인', '만들었습니다그리고', '꼴인데이건', '과몰입이라', '군대는', '쓰네', '해주라', '물어봤어요없다고', '억울함으로', '장녀', '그러시고', '계산을', '즐겨보곤', '보기만해도', '선택하라고', '소독하면', '키워야한다고', '눈막귀막인거', '평화가', '자기방만빨래도', '하게되면정말', '모르겠고그래도', '딸인', '올려주면', '안준', '왈너도', '유명하다고', '본격적으로', '홍보', '남편이니까여', '끝냈네요낼모레', '안함그러면서', '날라가야댐', '심한편', '개입니다', '대단하고발전한', '방들어옴', '모른다', '코로나전', '원인에', '회사는', '다녀서', '시작이', '않느냐면서', '없었습니다저도', '근데이영지', '못쓰는', '타긴', '알아듣게', '독박육아라고', '취직하고', '나이', '지경이예요', '필요없고', '남편다이어트하는걸로', '후보로', '수험생활', '뒤집힘', '멸치토마토마리네이드', '진행된', '별로여서', '오자마자', '주말에도', '버전이냐', '레고나', '의아함을', '알려줌큐이런', '심정지가', '문자에', '안적고', '커뮤와', '들어보시고', '진이', '화나다가도', '어 ...

# %%
from kiwipiepy import Kiwi, Option

kiwi = Kiwi()

Kiwi(
    num_workers=0, 
    model_path=None, 
    load_default_dict=True, 
    integrate_allomorph=True
)

inputs = wordlist

kiwi.extract_words(inputs, min_cnt=1, max_word_len=10, min_score=0.25, pos_score=-3.0, lm_filter=True)
# Out:
# [('부모님', 1.595139980316162, 86, -0.7513513565063477),
#  ('시부모님', 0.6396676301956177, 22, -0.4865383505821228),
#  ('서이것저것', 0.6229374408721924, 6, -1.3246546983718872),
#  ('애견동반', 0.6011443138122559, 8, -1.9989718198776245),
#  ('재난지원금', 0.5066719651222229, 6, -2.988631248474121),
#  ('엔시티', 0.4403059780597687, 9, -2.824829339981079),
#  ('일반칼국수', 0.41616111993789673, 9, -1.920362949371338),
#  ('투바투', 0.3939288854598999, 7, -2.1660144329071045),
#  ('스타일리스트', 0.3828323781490326, 5, -0.03425504267215729),
#  ('가스라이팅', 0.37034255266189575, 7, -1.4234473705291748),
#  ('요남편', 0.33296629786491394, 37, -1.3809949159622192),
#  ('스트릿우먼파이터', 0.31777065992355347, 3, -2.6770336627960205),
#  ('선생님', 0.30616796016693115, 16, -0.2404392510652542),
#  ('니다남편', 0.2872423529624939, 16, -2.3050408363342285),
#  ('응원법', 0.27162525057792664, 8, -1.5448956489562988),
#  ('스우파', 0.2559112012386322, 10, -2.0608885288238525)]

# %%
kiwi.load_user_dictionary('new.txt')
# Out:
# 25

# %%
new_list = []
new_list = kiwi.extract_words(inputs, min_cnt=1, max_word_len=10, min_score=0.25, pos_score=-3.0, lm_filter=True)

new_list
# Out:
# [('재난지원금', 0.5066719651222229, 6, -2.988631248474121),
#  ('엔시티', 0.4403059780597687, 9, -2.824829339981079),
#  ('투바투', 0.3939288854598999, 7, -2.1660144329071045),
#  ('스트릿우먼파이터', 0.31777065992355347, 3, -2.6770336627960205),
#  ('스우파', 0.2559112012386322, 10, -2.0608885288238525)]

# %%
import sys

f = open('extract_words.txt', 'w')

for i in range(len(new_list)):
    f.write(new_list[i][0]+'\n')

f.close()
