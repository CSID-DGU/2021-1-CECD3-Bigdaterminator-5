# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import fasttext

# %%
# input_file = 'natepann.txt'
# model_name = 'model.bin'

# model = fasttext.train_unsupervised(
#     input = input_file,
#     model='cbow',
#     loss = 'hs',
#     ws = 11,
#     lr = 0.001,
#     dim = 300,
#     epoch = 5,
#     min_count = 10,
#     thread = 25,
#     verbose = 1
# )

# model.save_model(model_name)

# %%
from kiwipiepy import Kiwi, Option

# %%
kiwi = Kiwi()

Kiwi(
    num_workers=0, 
    model_path=None, 
    load_default_dict=True, 
    integrate_allomorph=False
)

# %%
#kiwi.load_user_dictionary('new.txt')
#사용자 사전 추가 부분 -> 아직 전부 분류 하지 못해 모두 NNP로 등록된 상태 + 점수 들어가 있지 않음

# %%
inputs = list(open('natepann.txt', encoding='utf-8'))

#품사 및 언어 모델 필터링 하지 않은 경우
kiwi.extract_words(inputs, min_cnt=1, max_word_len=15, min_score=0.25, pos_score=-3.0, lm_filter=False)
# Out:
# [('습니다', 2.3767762184143066, 78, -5.113248825073242),
#  ('더라구요', 1.6216429471969604, 22, -2.834760904312134),
#  ('세븐틴', 1.2953639030456543, 17, -2.0750396251678467),
#  ('부모님', 1.174511194229126, 47, -1.0527305603027344),
#  ('방탄', 1.0854524374008179, 77, -2.0702643394470215),
#  ('입니다', 1.0122243165969849, 34, -4.707210540771484),
#  ('합니다', 0.9972155690193176, 38, -5.300004005432129),
#  ('결혼', 0.9925245642662048, 79, -1.8034230470657349),
#  ('방탄소년단', 0.9602351784706116, 17, -2.4663612842559814),
#  ('예비신랑', 0.9363517761230469, 20, -1.2639905214309692),
#  ('스트레이키즈', 0.8020613193511963, 5, -2.1006152629852295),
#  ('빅뱅', 0.72832852602005, 11, -2.3235023021698),
#  ('몬스타엑스', 0.6272661089897156, 6, -4.223088264465332),
#  ('더보이즈', 0.6040971279144287, 8, -2.790191650390625),
#  ('엄마', 0.5766282081604004, 71, -0.6888716220855713),
#  ('며느리', 0.5762567520141602, 26, -2.426273822784424),
#  ('대왕트래블', 0.5548834204673767, 8, -0.7859810590744019),
#  ('명절', 0.5140987634658813, 57, -1.7636749744415283),
#  ('얼굴', 0.4943852722644806, 23, -2.018155336380005),
#  ('었습니다', 0.49072548747062683, 12, -5.229389667510986),
#  ('하더라구요', 0.4864113926887512, 7, -2.91951322555542),
#  ('❤️', 0.4804530143737793, 2, -3.0973501205444336),
#  ('삐툴', 0.4804530143737793, 2, -5.3605499267578125),
#  ('니다', 0.4628031849861145, 210, -5.061764717102051),
#  ('새언니', 0.4567953646183014, 23, -0.8467673063278198),
#  ('엔하이픈', 0.4540952146053314, 6, -2.910804271697998),
#  ('엔시티', 0.4487341642379761, 10, -2.095034599304199),
#  ('는데', 0.41200944781303406, 221, -6.6045331954956055),
#  ('작은아빠들', 0.4033801257610321, 4, -2.9991989135742188),
#  ('남편', 0.39196935296058655, 69, -1.3626294136047363),
#  ('한테', 0.36318913102149963, 87, -3.5280210971832275),
#  ('친구', 0.3599937856197357, 50, -1.079941749572754),
#  ('싸움', 0.3591327965259552, 11, -1.8813295364379883),
#  ('상견례', 0.3496449291706085, 8, -2.494866132736206),
#  ('곱창', 0.3480762243270874, 5, -0.7896784543991089),
#  ('더라구요그', 0.3438056707382202, 6, -4.240703105926514),
#  ('다대왕트래블', 0.3298221826553345, 5, -1.5150139331817627),
#  ('시부모님', 0.32935193181037903, 12, -0.8014914989471436),
#  ('했습니다', 0.3224332332611084, 13, -5.111913681030273),
#  ('신혼여행', 0.31341829895973206, 7, -3.108649730682373),
#  ('였습니다', 0.3118297755718231, 8, -4.738924503326416),
#  ('상황', 0.309938907623291, 28, -1.1634290218353271),
#  ('객관적', 0.30879247188568115, 6, -4.002628326416016),
#  ('거든요', 0.3058018684387207, 10, -2.6300835609436035),
#  ('으로', 0.2972334325313568, 153, -4.7096076011657715),
#  ('에이티즈', 0.28540652990341187, 27, -3.1434943675994873),
#  ('추석', 0.2852768898010254, 18, -2.629866361618042),
#  ('안녕하세요', 0.2809191048145294, 7, -3.0157318115234375),
#  ('임신출산육아', 0.2775214612483978, 3, -2.0598337650299072),
#  ('사람', 0.2766411006450653, 54, -0.910228967666626),
#  ('드라마', 0.27209821343421936, 9, -1.9280537366867065),
#  ('감사합니다', 0.2682158946990967, 9, -5.8018341064453125),
#  ('타이틀', 0.26566237211227417, 5, -2.0749411582946777),
#  ('할머니', 0.26336920261383057, 25, -2.03214168548584),
#  ('생각', 0.2619818150997162, 86, -0.44358816742897034),
#  ('투바투', 0.2592220902442932, 14, -3.647313117980957),
#  ('탕비실', 0.25751444697380066, 5, -3.3408074378967285),
#  ('큰아빠', 0.2564701437950134, 11, 0.04965362697839737),
#  ('예비신부', 0.25270774960517883, 7, -1.7872761487960815)]

# %%
inputs = list(open('natepann.txt', encoding='utf-8'))
kiwi.extract_words(inputs, min_cnt=1, max_word_len=10, min_score=0.2, pos_score=-3.0, lm_filter=True)
# Out:
# [('부모님', 1.174511194229126, 47, -1.0527305603027344),
#  ('예비신랑', 0.9363517761230469, 20, -1.2639905214309692),
#  ('스트레이키즈', 0.8020613193511963, 5, -2.1006152629852295),
#  ('더보이즈', 0.6040971279144287, 8, -2.790191650390625),
#  ('대왕트래블', 0.5548834204673767, 8, -0.7859810590744019),
#  ('엔하이픈', 0.4540952146053314, 6, -2.910804271697998),
#  ('엔시티', 0.4487341642379761, 10, -2.095034599304199),
#  ('다대왕트래블', 0.3298221826553345, 5, -1.5150139331817627),
#  ('시부모님', 0.32935193181037903, 12, -0.8014914989471436),
#  ('임신출산육아', 0.2775214612483978, 3, -2.0598337650299072),
#  ('예비신부', 0.25270774960517883, 7, -1.7872761487960815)]
