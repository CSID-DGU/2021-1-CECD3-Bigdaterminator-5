# %%
import pandas as pd

df = pd.read_csv('natepann_Morphs.csv')
df.to_csv('natepann_Morphs.txt', sep = '\t', index = False)

# %%
def fileopen(data):
    
    #파일 불러오기 
    with open(data, 'r', encoding='utf-8') as file:
        
        text = file.read()
        
        splitdata = text.split()
        
        #리스트의 중첩된 부분 삭제하기 
        splitdata = list(dict.fromkeys(splitdata))
 
    return splitdata
 
 
if __name__ == '__main__':
 
    #파일1번 불러오기
    NewList1 = fileopen('natepann.txt')
    
    #파일2번 불러오기
    NewList2 = fileopen('SentiWord_Dict.txt')
    
    #파일3번 불러오기
    NewList3 = fileopen('sejong.txt')
    
    # 파일 1번에는 포함되고 파일2번에는 포함되지 않은 맴버 출력 
    #print(list(set(NewList1)-set(NewList2)))

    wordlist = list((set(NewList1)-set(NewList2))-set(NewList3))
    
    print(wordlist)
# Out:
# ['작다는', '컸던', '식으로회초리로', '가서보살피고', '학생회장', '신형', '힘내볼게요안녕하세요', '도둑취급했다', '생각했구요근데', '심각한거야', '김민주그리고', '합성이야', '토할뻔함하루', '안듣나', '비교되요', '엄마라고', '커버보고', '받아가고', '까랫냐', '일들', '했잖아요에이비식스웅', '소식을', '여쭤보는거라', '무얼하든', '어머님은', '즐기다보니', '이것', '한공기', '들어왔어요대', '하지않냐면서요실제로', '여자애들이라며', '낳기', '저희집에서', '해라', '지방까지주말마다', '장면인데', '프듀팬들', '아미들', '맞나봐', '소중했다그렇게', '박아두어헤어진걸로', '컴백했어더블타이틀', '쨈이랑', '안된다', '오라함너무', '온갖욕', '긴글', '기관에', '장레귤러', '사업때문에', '박지민', '대들', '싸우지않는데', '했는데요', '캄캄합니다저는', '컸고그오빠가', '가야한다는입장이고', '얼평하면서', '소원이였던', '연휴', '먹으면', '먹어요그것', '돌봐주길', '보러가는', '간거랑', '의사자격없으면', '안키웠죠저도', '발언들도', '아웃오브안중폰', '찍어놈경찰이', '가서같이', '욕하고', '일정이', '문제가', '세포들에서', '피곤해서', '선수', '있잖아', '우정도', '일등시민권을', '실베', '생겼다', '입는', '자유인데암튼', '자매', '엄마랑', '네이트판', '이석훈과', '월클', '소집해서', '말안한거라고', '컴백곡', '좋아하던데', '열일루비가', '양해', '없긴했는데요', '슬픈자리에서', '무서우면', '만든', '넘어지자마자', '설치할수도', '봤는데', '잘해준다', '후회할거라는둥', '니네', '하기전인데', '일주일에', '예정이니', '걔네', '몬스타엑스', '하게될수도', '쪽이', '아닌', '내라는', '했던', '마르진', '하는건가요당연히', '젖어있고', '어울리기도', '결혼은', '자기는', '힐', '이게', '모르쇠하네요', '우리도', '내주기엔', '믿어도', '소개해주면', '원해야', '돈돈돈', '들어가겠습니다저는', '얘길', '길어지면서', '시간이였어요거의', '다니면', '틴트', '계시지만음', '개인의', '집게손가락만', '바꿈마지막은', '혼자계신', '눈빛이고', '모임에', '콧구멍', '잇어', '채팅에', '찾아보다가', '장사하시느라', '남자한테', '안그러는건가다', '잘해주시는', '그런거', '임신전', '거기다', '저에게도', '애교라며', '하나님이', '셔누랑', '데뷔부터', '고개돌려서', '상향', '시민권', '둘이', '작은엄마들', '탕이나', '반응은', '꿀팁이나', '새언니랑', '살아가고', '제니나', '계란후라이나', '포르투갈의', '세면대는', '게임을', '지랄났네발', '없어요시댁에', '남습니다', '재수없다고', '입장임작은', '걸림저', '라는게', '심리는', '왁자지껄한', '참여했어데자부는', '팬이', '합니다그리고', '자체로', '올라오면서항상', '식탐', '행복한일만', '동네에', '안가져다', '흙수저라', '찌면', '손이', '연로하심', '만지고', '싶을까요', '말하지말라그랬구요근데', '가져왔어진짜', '밥도', '좋아했고다투기라도', '않았어요엄마가', '여자들끼리', '가지마세요그리고', '투바투', '그런거면', '뭐하시는거냐고', '길게', '초라', '동의합니다', '존경했거든요형', '느꼈는지', '재료도', '아린보다도', '김치', '스틱형으로', '구사하는', '자료공유를', '탑', '시원시원해서', '돈도', '보내세요', '지니네', '찍어봤닼와씨', '않나요이러다', '짝사랑', '걱정이라고', '며느리보다', '찾기', '먹을꺼', '어차피친구니까', '회사가', '입원', '식이네요요즘', '빼고', '어쩔수없었다', '자극짤', '평일은물론이고', '투쁠한우만', '수빈', '공공연한', '올려놓은', '궁금한', '억까글들로', '김치랑', '눈멀어', '아기', '한포기도', '홈마', '그건', '포기하셨습니다나이먹고', '않았어', '바랐었거든요그런데', '뭐라해서', '같다이뻐', '떠나서요저는', '안맞다', '단어', '소중해서', '있어야되지', '비우고', '않구요저는', '불리하여', '여사친', '없구요', '연락와서', '했고아침저녁', '굴욕적이고', '할거라', '해준것도', '지어진다는', '예배드리는걸로', '번지고', '예비신랑', '처가명의', '말씀하시나요형제관계', '판에서', '건들면', '하고솔직히', '올림픽', '빌보드', '하는거야', '헤어진걸로', '시국탓에', '맞지않냐', '아기가', '뭣보다', '부담한', '얘네들도', '따졌더니기억안난다고', '전업일', '대통령', '귀엽슙니당', '거절함전화', '아르망', '뷰티톡', '못하겠더라근데', '남편이죠서방님이랑', '힘들어', '뷰티톡과학하고', '방에들가셔서', '이친구를', '울엄마', '느낌이었습니다게다가', '남자들전부', '사오려고', '극도로', '남기더라도', '치고돈', '에이프릴', '같았고', '그래보여', '두부', '신입으로', '수술한', '최강창민동방신기위', '생각한', '카페까지', '친정도', '장무한적아', '아이키가', '월초', '힘인가트와이스', '복귀한것을', '어딘지도', '어깨에', '부인하고', '요리하고', '무개념', '봐서', '비치는거보면', '도와주세요', '먹금에다', '비용도', '뭔가', '보여주면서', '수진이라면', '트위터와주는거', '중요했겠죠그런데', '뮤즈', '탐인지', '카페', '뮤비밤하늘유희열의', '못해줬어요', '안좋다는', '했대요듣고있던', '코로나로', '싶을', '연습하다보면', '뒹굴거리면서', '달아주신', '구라라고', '땅도', '평균적으로', '의미변화', '종년인가요', '시작', '놀러갔을때', '힘주고있음전정국', '되나싶을정도로', '비교한건', '없고요', '두세차례', '웬만하면', '시댁이', '쌍커풀', '상대하는데', '대학생', '젊게', '알려지지', '잠깐이지만', '혐오스럽답니다애를', '초반인데', '울렁거려요', '키우면서', '수준', '나기', '재합류', '원필', '일하면', '변경하여', '만들겠나요관련', '뜯어내려고만', '읽어주셔서', '아프니', '생기부', '개거품을', '달라야', '밑바닥', '스우파기때문에', '안해줌', '먹는다는', '꾸기', '있겠구나싶기도하고남편이', '억짜리', '지원해서', '아파보인다고', '해도', '안맞아서', '부치는게', '한들', '저녁은', '낳겠다니', '유리병에', '여연갤에서', '갈겨버리고', '에쁜', '솔직하게', '부모는부모', '다녀서', '망상이다라고', '서서', '여동생도', '지역에서는', '먹은', '거임', '미안했습니다남편은', '도와줘도새언니', '찍었어그리고', '도전해보겠다고', '편들기', '복받으세요', '살고', '당분간은', '상관없이교대근무', '저에겐', '없지만제가', '연애하고', '제사명절', '조언좀', '파하고', '칭찬은', '김장에', '시부모님중', '살아', '비교한거', '생각햇는데', '보여서', '데자부랑', '시누이도', '계시더라고요', '개빡쳐서', '뉘앙스였습니다저는', '올라왔는데', '재난지원금도', '하는데본인은', '똑같당', '당하고서', '준다고', '딸이였에', '트름하며', '바라시고', '거냐고', '높아져', '어려워하셔', '주시는', '제일친했던', '오기', '지금은', '노력했던', '예고', '여기서부턴', '엄마도', '어머니와서투른', '경쟁하면서', '탈락', '편이', '안달렸어요', '마시던', '성씨는', '목표가', '예리가', '알았다사랑에', '하구자는데', '있었습니다', '찌개', '인기탑들이랑', '싶은거로', '생겼을', '내가', '그오빠한테', '자가', '한살차이', '마시라고' ...

# %%
from kiwipiepy import Kiwi, Option

kiwi = Kiwi()

Kiwi(
    num_workers=0, 
    model_path=None, 
    load_default_dict=True, 
    integrate_allomorph=True
)

inputs = wordlist

kiwi.extract_words(inputs, min_cnt=1, max_word_len=10, min_score=0.25, pos_score=-3.0, lm_filter=True)
# Out:
# [('부모님', 1.360173225402832, 30, -1.239998459815979),
#  ('예비신랑', 1.1953601837158203, 11, -1.137906789779663),
#  ('스트레이키즈', 0.9027248024940491, 5, -2.1006152629852295),
#  ('더보이즈', 0.8272835612297058, 6, -2.3349757194519043),
#  ('에이티즈', 0.6996692419052124, 11, -1.6709916591644287),
#  ('대왕트래블', 0.5944437384605408, 8, -0.7859810590744019),
#  ('엔시티', 0.5782291889190674, 8, -1.5798336267471313),
#  ('엔하이픈', 0.5442987084388733, 4, -2.2882864475250244),
#  ('시부모님', 0.4234004020690918, 9, -0.7022450566291809),
#  ('다대왕트래블', 0.34669506549835205, 5, -1.5150139331817627),
#  ('임신출산육아', 0.29272204637527466, 3, -2.0598337650299072),
#  ('예비신부', 0.2905968725681305, 5, -1.8848686218261719)]
