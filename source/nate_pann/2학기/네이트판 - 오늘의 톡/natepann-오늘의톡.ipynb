# %%
import requests
import time
import os
import sys
import re
import io
import json
import csv
import openpyxl
import pandas as pd
import numpy as np
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
from bs4 import BeautifulSoup
from selenium.webdriver import Chrome
from selenium.webdriver.common.keys import Keys
from konlpy.tag import Komoran, Okt
from nltk import Text
from pykospacing import spacing
import kss

# %%
browser = Chrome()

titles = []
links = []

date = input("시작날짜 입력(eg.20210920):")

#링크, 제목
for i in range(0,3):
    
    for j in range(1,3):
        browser.get("https://pann.nate.com/today/view/" + str(date))
        soup = BeautifulSoup(browser.page_source, 'html.parser')

        first_list = soup.find('div', {'class': 'bridge_talk'}).findAll('li')

    for li in first_list: 
        t = li.find('a')
        real_link = 'https://pann.nate.com' + t.get('href') 
        links.append(real_link)
    
    for li in first_list:
        t = li.find('a')
        real_title = t.get('title')
        real_title = spacing(real_title)
        real_title = re.sub('[ㄱ-ㅎㅏ-ㅣa-zA-Z0-9]', '', real_title)
        real_title = re.sub('[\xa0|0xed]', '', real_title)
        real_title = re.sub('[-=+_★♥♡,#/\?:╋^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》—;]','',real_title)
        titles.append(real_title)
        
    date = int(date) + 1

# print({'제목': titles, 'url': links}, sep='\n')
# Out:
# 시작날짜 입력(eg.20210920):20210920
# {'제목': ['아기냥 호빵이 ', '항상 친절하고 진심으로 대하려 애쓰는데 나는 늘 혼자네', '사진은 어떻게 잘 찍을 수 있는 거니', '엄마의 감정 쓰레기통이었던 나 이런 마음이 혼란스러워', '자가 격리 중인 시어머니께 안부 전화 좀 하라는 남편', '다 말랐는데 종아리만 살이 안 빠지는 이 유가 뭘까', '사소하지만 엄마가 행복해 할 만한 일이 뭐가 있을까', '명절에는 무조건 시댁 먼저 가는 게 예의이고 도리인가요', '전 여자 친구의 물건들을 버리지 않는 남친의 심리', '다들 첫 직장에서 받은 첫 성과급 어디에 쓰셨나요', '돌아가신 할머니가 너무 보고 싶은데 시간이 약일까요', '추석 전 신랑과의 언쟁 누가 더 잘못한 건가요', '나의 동거 묘 도 칠이  분리불안', '살인데 제대로 된 친구가 한 명도 없습니다', '직장 사수에게 차려야 하는 신입의 예의 뭐가 있나요', '살에 신입으로 취직이 가능할는지 모르겠습니다', '회사 사장의 폭언 현명하게 퇴사하는 방법이 뭘까요', '아기냥 호빵이 ', '항상 친절하고 진심으로 대하려 애쓰는데 나는 늘 혼자네', '다들 친구 관계를 어떻게 유지하고 계시나요', '민폐 끼쳐놓고 되레 예의 없게 구는 아랫집 사람들', '너무 운동을 안 하는 남편 운동시킬 수 있는 방법', '식단 하는 나보다 살이 더 잘 빠지는 라면 먹는 지인', '삶의 원동력 사는 이유 하루하루 어떻게 살아가시나요', '사소하지만 엄마가 행복해 할 만한 일이 뭐가 있을까', '명절에는 무조건 시댁 먼저 가는 게 예의이고 도리인가요', '내가 직접 만든 커플링인데 어때', ' 감량 후에도 여전히 자존감이 낮아요', '남편의 상습적인 거짓말 누구 잘못인지 꼭 좀 봐주세요', '가난한 건 죄 나 스스로가 너무 한심하고 찌질해 보여', '드디어 이렇게 끝이 난 연애 참 허망하고 비참하네요', '나의 동거 묘 도 칠이  분리불안', '살인데 제대로 된 친구가 한 명도 없습니다', '너무 운동을 안 하는 남편 운동시킬 수 있는 방법', '식단 하는 나보다 살이 더 잘 빠지는 라면 먹는 지인', '삶의 원동력 사는 이유 하루하루 어떻게 살아가시나요', '아파트 베란다에서 담배를 피우시는 부모님', '누나 노릇 안 한다고 자꾸 내게 잔소리를 하는 외할머니', '다 이렇게 회사 생활하는 건데 내가 나 약한 건지', '브라이덜 샤워 준비 비용은 원래 친구가 다 내는 건가요', '살에 모은 돈 만 원 돈 강박증이 너무 심해요', '다들 친구 관계를 어떻게 유지하고 계시나요', '민폐 끼쳐놓고 되레 예의 없게 구는 아랫집 사람들', '살에 신입으로 취직이 가능할는지 모르겠습니다', '회사 사장의 폭언 현명하게 퇴사하는 방법이 뭘까요'], 'url': ['https://pann.nate.com/talk/362516196', 'https://pann.nate.com/talk/362524427', 'https://pann.nate.com/talk/362514113', 'https://pann.nate.com/talk/362517760', 'https://pann.nate.com/talk/362516569', 'https://pann.nate.com/talk/362513402', 'https://pann.nate.com/talk/362529242', 'https://pann.nate.com/talk/362530480', 'https://pann.nate.com/talk/362527107', 'https://pann.nate.com/talk/362520256', 'https://pann.nate.com/talk/362513373', 'https://pann.nate.com/talk/362531134', 'https://pann.nate.com/talk/361973002', 'https://pann.nate.com/talk/362041415', 'https://pann.nate.com/talk/362029618', 'https://pann.nate.com/talk/362026086', 'https://pann.nate.com/talk/362030931', 'https://pann.nate.com/talk/362516196', 'https://pann.nate.com/talk/362524427', 'https://pann.nate.com/talk/362013655', 'https://pann.nate.com/talk/362019764', 'https://pann.nate.com/talk/362021009', 'https://pann.nate.com/talk/362020785', 'https://pann.nate.com/talk/362034692', 'https://pann.nate.com/talk/362529242', 'https://pann.nate.com/talk/362530480', 'https://pann.nate.com/talk/362202528', 'https://pann.nate.com/talk/362186076', 'https://pann.nate.com/talk/362193145', 'https://pann.nate.com/talk/362190127', 'https://pann.nate.com/talk/362190384', 'https://pann.nate.com/talk/361973002', 'https://pann.nate.com/talk/362041415', 'https://pann.nate.com/talk/362021009', 'https://pann.nate.com/talk/362020785', 'https://pann.nate.com/talk/362034692', 'https://pann.nate.com/talk/362186437', 'https://pann.nate.com/talk/362190927', 'https://pann.nate.com/talk/362193030', 'https://pann.nate.com/talk/362191787', 'https://pann.nate.com/talk/362189855', 'https://pann.nate.com/talk/362013655', 'https://pann.nate.com/talk/362019764', 'https://pann.nate.com/talk/362026086', 'https://pann.nate.com/talk/362030931']}

# %%
#본문
txt = []
    
for i in links:
    try: 
        res = requests.get(i)
        res.raise_for_status()
        res.encoding = None            
        html2 = res.text
        
        soup = BeautifulSoup(html2, 'html.parser')
        contentArea = soup.find("div", {"class" : "viewarea"})            
        parags = contentArea.findAll("div", {"id" : "contentArea"})

        content = ""

        for parag in parags:
            content += parag.text
#         content = re.sub('[ㄱ-ㅎㅏ-ㅣa-zA-Z0-9]', '', content)
#         content = re.sub('[&nbsp;|\n|\t|\r]', '', content)
#         content = re.sub('[\xa0]', '', content)
#         content = re.sub('[-=+_★♥♡,#/\?:╋^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》—;]', '', content)
        content = re.sub('[^ ㄱ-ㅣ가-힣]','',content)
#         content = spacing(content)
        
        txt.append(content)
             
    except HTTPError as e:
        txt.append('')
    except URLError as e:
        txt.append('')
    except AttributeError as e:
        txt.append('')
        
print(txt)
# Out:
# ['꽉 찬 개월을 향해가는 호빵이워낙 운동량이 적어서인지 많이 먹지 않아도 통통냥보는 사람들마다 이리 큰 냥이 본적 없다 해서 걱정입니다 키로 다이어트 시켜야 하나친구네에서좋아하는 자리사랑하는 이불 동굴욕하는 거 아님목욕하고 말리던 중 탈출옷장 안목욕하면 드러나는 애기애기 모습매트리스 가로 지르기보기만 할 뿐절대 탐내지 않음잘 때도 귀엽고쩍벌도 귀엽고제 눈에 왕콩깍지   뭘해도 예쁜 우리 호빵풍성한 한가위 보내세요 ', '항상 친절하려 애쓰고잘 대해주려 애쓰고늘 진심인데항상 혼자야나를 피한다는것도 느껴지고 불편하게 본다는것도 알겠는데이유를 모르겠어뭘 노력해야할까내가 연락하지 않으면 나를 먼저 찾는이 하나 없고광고 카톡 이외엔 카톡도 없어다른 사람들은 카톡에 전화가 울리는데 내 폰은 늘 조용씁쓸하다', '아마 이게 살면서 가장 잘찍었다고 생각하는 사진임나도사진잘찍고시퍼 왜 계속찍어도 그대로지그리고 사진에 사람이 들어가면 배로 더 어려워짐ㅠㅠ ', '명절을 앞두고 친정에 가야하나 사회초년생일때 첫째오빠 집을 사야하는데 청약이 없다며 내 명의로 된 청약과 대출을 빌리려던 친정엄마 초년생 일 시작한후부터 같이 사는데 생활비 집안일 요구 첫째 오빠 둘째오빠 일 안하니 용돈 보내라는 요구  결혼식 돈 다 가져가심 내역도 모름 임신 당시에는 무직이었으나 생활비 요구 집안일 요구 출산한지 한달도 안된차 매일 일 시키시고 자존감 갉아먹는 말 퍼부으시고 감 나만 보면 돈없다 먹고살기 힘들다 돈 빌려줘라 하시는데즐길거 다 즐기시고 하고싶은거 사고싶은거 다 하고사심건강이 심하게 악화되어 병원에서 몇차례 수술받았는데 나 기다리는동안 영화 보고 오심 아이 낳을때도 밥 먹으러가심 아이 낳고 산후조리에 일절 터치 안하셨으면서 내 몸 관리 안했냐함 손주 옷 한벌 사주고나면 그 돈 갚느라 힘들다 하심 참고로 사달라 한적 없음 아이가 밖에나가 말 안들으면 주위 사람들에게 내가 가정교육 잘못 시킨거라며 내 욕을 같이 함 ㅋ명절마다 돈 안주냐 이러시는데 담주 명절인데 돈 드려야하나 고민하다가 지금까지 키워주신 은혜가 있는데 이딴 생각을 하는 내가 불효녀같고 혼란스러움 난 살아 생전 엄마의 감정쓰레기통으로 살아왔음 살면서 해달라는거 다 해드렸는데 이젠 암것도 해드리기 싫은 마음 드는데 혼란스러움  ', '어머님이 가게를 하시는데확진자가 다녀갔데요그래서 어머님이 검사 후 음성이신데주 격리하게 되셨데요그래서 남편이 저보고 어머님한테 전화좀하래요하든 안하든 알아서 할거고하라고 해서 하긴할텐데전화하라고 왜시키는건가요 ', '다말랐어요 허리는 인치 팔뚝 전부요 오죽 말랐으면 등에 뼈밖에없고 허벅지도 엉덩이도 살없어서 바지는  입는데 종아리 안들어가서 못입어요ㅜㅜㅠ근데 종아리만 너무 굵어서 운동 진짜 미친듯이 년째 근력운동이랑 다하거든요 안하는게 없어요 근데 종아리만 안빠지는 이유가 뭘까요 보니까 셀룰라이트가 많이 두꺼운거같은데 이것때문일까요 찹고로 엄마는 다리미인이셨어요 그리고 다리 붓기도 아닙니다 붓기없이 말랑말랑해여 ', '요즘 잘 못챙겨주고 방에만 있는 거 같아서  ', '안녕하세요 얼마전 결혼한 새댁입니다이번 추석 명절을 앞두고 또 일이 생겼네요처가댁 시댁 저희 모두 같은 지역에 살고 있고처가댁은 추석차례상을 차리고 시댁은 차리지 않습니다시댁은 시어머니 혼자 계셔서 명절 기분 낼 정도로 간단한 음식만 하시는데요저는 차례상을 차리는 처가댁을 도와드리고 시댁에 가고 싶은데시어머니께선 차례상을 차리지 않더라도 무조건 시댁이 먼저라는생각을 하고 계십니다그게 예의이고 도리라고 하시고요처가댁을 먼저 간다는 말씀을 드리진 않았지만 아마 알게 되시면 엄청 노발대발 하실게 분명합니다며칠 전 시어머니께 전화와서 혼자 계셔서 차리지 않던 차례상을제가 시집오니 차례상을 한 번 차려보자고 하는 거 에요너가 아무것도 모르니까 내가 한 번 차례상 같이 차려보려고 하는 거다 이렇게 말씀하셨지만제가 느끼기엔 몰라도 되고 굳이 안 알려 주셔도 되고 저희 집에서도 충분히 보고 도와드려서 아는데 또 이렇게 말하면어디서 배워먹은 버릇이냐 그러네요 ㅎ원래 시어머니들은 며느리가 생기면 저렇게 부려먹고 싶어서 안달나나요시댁은 차례상을 차리지 않는데도 먼저 가야하나요시댁 오는게 싫으면 결혼 다시 생각하라네요 ㅋㅋ ', '사귄지는 년정도 커플임중간에 몇번 헤어지고 헤어짐중에 한번은 길게 년 헤어졌었음그 사이동안 서로 다른연인 만나다 이번에 다시만나게 되고  다시 만난지 얼마 안되서 남친집에 갔었는데 전여친이 준 편지들증명사진여성용품 등 서랍에 그대로 있었음 저는 그걸보고 화가나서 남친보고 빠른시일내에 버리라고 말했었는데 주가 지난 후 다시 갔을때에도 그대로 있길래 화가나서 뭐라했더니  이젠 맘도 없어서 까먹었고 어차피 마음에도 없어서 빨리 치워야겠다는 생각조차 안했다고 그냥 저것들의 존재를 까먹고있었다고 그래서 못치웠다고 변경하길래 내가 뭐라했더니 왜이렇게 쪼으냐는 식으로 말하면서 알아서 치울꺼니깐 신경꺼라 하는거 남친이 쪼는거 엄청싫어함그리고 계속 쪼으니깐 그럼 나보고 그럼 왜 서랍은 왜 열어보냐고  니가 그렇게 싫으면 이제와서 니가 먼저 치우면 되잖아 그러길래 니가 치워야하는거 아니냐 내가 왜치우냐 아님 지금 내가 치울께 달라니깐 그냥 자기가 알아서 하겠다고 했음   결국엔 남친집에 남친없을때 내가 다 갖다버렸음아직 남친은 모르는지 아는지 모름ㅜㅜ근데 진짜 이사람은 나를 만나는 다른사람을 만나든 전 여친 흔적을 잘 안지우는 사람인데 예전에도 다른 전여자친구 흔적도 있었고 나랑 헤어지고 다른여친 생겼을때에도 내사진 안지우고 발견될때까지 놔뒀었음 발견해도 잘 안지웠음  안지우는건 그렇다 치고 현 여친이 알게됐거나 발견했을경우엔 여자친구를 위해서 당장 버려야하는게 당연한거 아님 이런 남자는 무슨 생각인지 진짜 궁금해요ㅜㅜㅜㅜ 자기 말로는 너무많고 귀찮다라는 변명도 늘어놨는데 뭐죠 이심리는', '첫직장 첫입사 한 회사에서 첫성과급을 받았어요 어마무시하게 큰 돈은 아니지만 의미있게 쓰고싶어서요ㅠㅠ 어디에 쓰면 좋을까요 아직 가족들한테 말은 안 해서 제가 생각하는건 전부 한켠에 모아두기 부모님 용돈드리기맛깔난 식사대접 갖고싶었던거 사기인데 큰 돈이 아니라 세가지 전부 하긴 어려울거 같고 한 두가지 정도는 묶어서 할 수 있을 거 같아요 이외에도 좋은 방법 있으면 추천해주세요', '제가 속마음이나 깊은 얘기를 맘 놓고 털어놓을 데가 없어서 혼자 삭히다가 오늘은 할머니가 너무 보고싶어서 여기에라도 끄적여봅니다 부모님 앞에서도 할머니가 보고싶다는 말을 못하겠어요 원래 가족한테 속마음을 잘 털어놓지 않기도 하고 슬퍼도 저보다 부모님이 더 슬프겠지 싶어서요 그래서 가족 중에도 이런 얘기를 마음편히 털어놓고 싶은 사람이 없어요할머니가 돌아가신 지 몇달이 지났지만 아직도 할머니 사진을 제대로 못보겠어요 할머니 사진만 보면 눈물이 나고 할머니가 살아계실 때 잘 해드리지 못한 것만 떠올라서 저 스스로에게 화가 나기도 하고요 너무 죄스럽고 한스러워요여전히 할머니가 돌아가신게 믿기지 않아요 할머니 말투 표정 걸음걸이 다 기억나는데요 그래서 더 고통스러워요 머릿속에선 동영상처럼 다 보이는데 실제로 볼 수가 없으니까요 가슴이 찢어질듯 너무 아파요 낮이나 오후에는 밖에 있거나 가족들과 있으니까 할머니 생각이 나도 꾹꾹 참으면서 티를 안내는데 늦은 밤에 방에 혼자 있으면 할머니 생각에 눈물이 계속 나요 혹여 꿈에서 뵐 수 있을까 매일밤 할머니 생각을 하면서 자는데요 아직 한번도 나타나지 않으셨어요 할머니한테 해주고싶은말이 너무 많은데 영원히 못할까봐 너무 무서워요 너무 보고싶어요 정말 시간이 약인걸까요 늦은밤 할머니가 너무 보고싶은 맘에 적어본 글이었네요긴 글 읽어주셔서 감사해요 ', '', '고양이도 분리불안이 있다고 해서 도칠이는 어떤가 관찰을 해보았음고양이 분리불안은 집사가 외출을 하면 문앞에 몇시간이고 계속 서있는다고 했다집사가 출근위해 집밖을 나가고 지하철역 도착해서 카메라 확인시간까지 분도 안걸림출근위해 집밖 나간지 분도 안됐음도칠이 월요일날 분리불안 관찰 모습화요일 도칠이 분리불안 관찰 모습수요일도칠이 분리불안 관찰 모습발베개 뒤에 숨어서 머리만 내밀고 자고 있음목요일도칠이 분리불안 관찰 모습금요일도칠이 분리불안 관찰모습가끔 아주  ...

# %%
#형태소 분석
komoran = Komoran()
okt = Okt()


title_morphs = []
txt_morphs = []
    
for i in titles:
    title_morphs.append(okt.morphs(i))
    
for i in txt:
    txt_morphs.append(okt.morphs(i))
    

nate_dict = {
    '제목' : titles,
    '본문' : txt
}

df = pd.DataFrame(nate_dict) 
df.to_csv('natepann.csv', index=False, encoding="utf-8-sig")

  
morphs_dict = {
    '제목 형태소' : title_morphs,
    '본문 형태소' : txt_morphs

}


df2 = pd.DataFrame(morphs_dict)
df2.to_csv('natepann_Morphs.csv', index=False, encoding="utf-8-sig")

browser.close()
