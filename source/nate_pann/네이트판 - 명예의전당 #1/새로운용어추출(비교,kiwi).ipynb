# %%
import pandas as pd

df = pd.read_csv('natepann_Morphs.csv')
df.to_csv('natepann_Morphs.txt', sep = '\t', index = False)

# %%
def fileopen(data):
    
    #파일 불러오기 
    with open(data, 'r', encoding='utf-8') as file:
        
        text = file.read()
        
        splitdata = text.split()
        
        #리스트의 중첩된 부분 삭제하기 
        splitdata = list(dict.fromkeys(splitdata))
 
    return splitdata
 
 
if __name__ == '__main__':
 
    #파일1번 불러오기
    NewList1 = fileopen('natepann.txt')
    
    #파일2번 불러오기
    NewList2 = fileopen('SentiWord_Dict.txt')
    
    #파일3번 불러오기
    NewList3 = fileopen('sejong.txt')
    
    # 파일 1번에는 포함되고 파일2번에는 포함되지 않은 맴버 출력 
    #print(list(set(NewList1)-set(NewList2)))

    wordlist = list((set(NewList1)-set(NewList2))-set(NewList3))
    
    print(wordlist)
# Out:
# ['찌잉생각지도', '춤짱', '지났을때대', '당했기', '같아요언제까지', '미역국같은', '연락할껄', '케빈', '찌질이만', '가기싫어서', '거리예여정말', '자연스러운', '씹터톡에', '민혁님이', '만나자고', '노랑색', '된장찌개사태', '잘하리라', '사건을', '채워졌습니다', '화가나는건', '다섯여섯번씩', '골라줘', '멍청이는없지그냥', '준비한', '언덕쪽', '줬는데', '탄도', '건지', '과였기', '행동들', '옷빨이', '저년들', '오아이오아이', '제통장에', '듣지', '안되고주행좀', '진담', '두개가져갔엇음', '보여야', '끼를', '처음인데', '친자식도', '주목받고', '공유해서', '정도가남았고', '남자애들', '검색해보니', '느꼈고', '소설을', '얼마안되서', '왔어요새언니가', '살리기가', '사랑받는', '계시구요저희가', '있는중라라봉하고', '부모님가게에서', '음침', '쓰러진', '쿠션사고싶은데', '고기능', '소민', '사돈', '하고전문', '하시더라고요아이러니한건', '시댁에도', '잊혀진체', '되어있는', '톰브라운', '동네에', '차지하게', '롬앤', '얼굴뵙고', '목록도', '직급도', '다른집에서', '친모이신', '죽이고', '올텐', '원본장에', '여부를', '컸을', '맘이', '선택을', '모으는', '겪어', '개잘생겼어', '판녀인거', '해결해야지', '화냈고', '어머님이랑', '저에게도', '다시만날건', '꼬인', '궁금하네요', '되었어요', '담기', '요양', '타쓰는', '봤냐', '스쉽이라면', '하소연할', '장난아닌', '자료가', '푹신하고', '선배', '가는데', '얘기해보자네요제가', '폭팔을', '아랫집에서', '언매보다', '전화', '육아엔', '올라갔다', '믿냐', '과목', '스킨', '다르다고', '배려하게', '진정그리고', '죽은게', '그냥편하라고남자친구', '태어나면', '코트', '구석에서', '갇기로', '빼돌리는건', '장난도', '시아주버님한테돈을', '나온거고', '듣고도', '도로에', '생각날때', '싸우는거', '한국이', '오픈', '묶어보려고', '친정엄마', '통하여', '없습니다', '병원을', '그런가뭔', '생각해주세요', '됐었는데', '넘은적이', '눈은', '무대장인', '챙기기', '산모회복에', '없다네요다', '화내길래그런뜻으로', '말라함', '재능충만큼', '대화할때마다', '두분', '연애랑은', '계신데', '중이지만', '비싼걸팔고싶으셨겠지하며', '가능한데', '들겠어요반대로', '버리는거라고', '밝힌', '끝내기', '열받아서신혼초기에', '하니잘지내는지', '해야해요남친은', '작아요코로나때문에', '바라보며', '장난아니었다', '상황이고일단은', '볼때는', '라면도', '내용', '마시고싶으면', '알바야', '드는', '나던데', '좁혀서', '해놨습니다', '낳아', '소송중입니다년', '만년', '한번씩', '천여친', '못쳐', '회사만', '불러야한다고', '키는', '안해줘서포기하고', '하나님한테', '유치원에서', '실수에', '부탁해야하고대충사면', '되니까슴가', '여쭙고자', '찌는게', '공원에', '인생까지', '패냐', '쉬지도', '없어졌습니다주', '어려요원래는', '값아', '공격하겠네요필요없으니', '중순에', '던져', '같지', '받았고일', '대세요하며', '연애하다', '넣어둠남자사장', '트위터에', '나오길래', '늦어', '해놓고신랑이', '뷔', '별거없네요', '스트레스입니다그렇지않아두', '드실', '있나블핑', '넘었어요빌려준지', '천지', '돌려주셨다', '그랬다박하야사랑한다너의', '하는데평상시에는', '가게되었습니다예비시어머니께서', '하냐이', '노래불러야함', '왜이런걸까여운동도', '소리지르는', '하겠다함프니엘', '하신', '알수있나요결혼', '많관부비투비', '다가오면', '나왔고', '자신감이', '김소연드라마에서', '눈앞이', '오줌을', '경찰서에', '선택하면', '쇼타로', '아닌데왜', '보탤', '답변', '바랄게우리', '방법인가나도', '저희아이를', '힘드실지', '팁이', '걸려서', '어케', '우울해했는데그냥', '한거라던데', '아래서', '행복만하길', '수도권', '부족하다며만원을', '장애통합반', '졸거나', '알사람들은', '퇴원확인서와', '한두번은', '삼겹살', '물어봐서', '외출한김에', '청첩장을', '수건을', '그런걸로', '통영', '도전하게', '환승이별', '앨범은', '버리겠다고', '비공개', '사과하고', '억천만원을', '다녀오고', '최근에는', '했어요물론', '키스한', '없으면서데이트비용은', '유신이', '생각해보자고', '상동행동이나', '가사처럼', '잘사는', '아웃사이더', '조건으로', '왜저렇게까지', '말합니다', '대중들이', '가르쳐', '밥하기핑계가', '싶은건', '소리인데남친분은', '제출한', '소름돋아나만소름돋냐대충', '청원글도', '고역이예요대때도', '반응을', '이야기다', '찾는', '않은데', '브랜드고언니가할때자주사서그때마다뺏구있음헿난평소엔전초앰플쓰고가끔피부뒤집어진다여드름올라올것같다싶을땐오른쪽피부과앰플쓰고있어개인적으로는스킨로션보다는앰플쓰고단기간내에효과확실히봤어이건내가건성이라그럴수도있으니참고해줘다음은수분크림인데여름에도겨울에도정말중요한거야올영에서파는수딩젤같은거써도좋은데저닥터지가비싸긴해도진짜만족스럽고느낌도좋아내돈내산한첫화장품이야수분크림은아예정착했음오른쪽꺼는군대에서싸게파는거라고해서정가주고사기좀아깝기도한데진짜괜찮은것같아닥터지자체가올영에서세일을자주하니까세일노렸다가사는게이득임마스크쓰는요즘또픽서를안쓸수가없지왼쪽라이트벨벳미스트는기름종이역할을해주는픽서라서화장다하고살짝뿌려주면기름기좀잡아주는역할을하는미스트고가운데는베이스파우더전에그리고메이크업다끝나고뿌려서고정시켜주는역할로무난무난하게좋은픽서고오른쪽은수분감유지에되게좋고베이스하기전에화장안밀리게하고싶은사람들그리고고정시키고싶은사람들이쓰기딱좋아요건투쿨픽서인데얘는내돈내산한거메베대비가성비좋아서추가해봤어질문있으면댓글로받을게돈받은거없고언니한테받은거랑유튜브보고사본것들임프라이머안쓰는사람들많은것같아서프라이머도추가해봤어스킨케어끝나고화장하기전에프라이머를싹발라야화장발림성도좋고모공같은것도좀가려줘서난무조건필수로사용하는데모르는사람들이많더라구왼쪽은내가수능끝나고제일처음샀던프라이머베네피트는알사람들은알텐데모르는사람보여주려고갖고온거고', '낳아서', '내시며', '니네집은', '코빼기도', '못하였습니다병원', '네이버카페', '아니라맞벌이에', '요청하였고', '비해서', '보니까이제는', '오르내리는게', '떨어져서', '앱도', '물어인데', '팔찌를', '절친이고', '밀었겠지만', '세은휘', '물어봣대', '상처이기에', '되길', '합니다만', '물으니돈만', '전체에서', '자컨내면', '아파트도', '바쁘셨는지', '모고', '반집앞', '같은건', '모르겠어서', '부산이랑', '캐릭터이다뮬란은', '피드백은', '아가미', '소년에', '생각할까요악마', '하시면서', '날들을', '공지하는', '잘하시는데큰', '힘들었어요뭐든', '최소', '아니였고외고', '스탈이라', '태연한테까지', '없고거기다가', '유튜브에서', '따라하는거', '나갔다', '좋았어요술자리', '들었을까', '다운받아같이보고돈은', '신랑조차', '봐주라', '많은거', '동생집', '신부지만', '안주고', '짜증날려고', '일체금지대소변모두', '묻히거나', '어그로인데', '근무한', '좋겠습니다익명으로', '생각할수없음', '바란다는', '곡에서도', '생각들이', '남자분이시니까남한테', '따지지도', '나온사람만', '견디는데', '연락할', '거잖아요솔직히', '전했어요남편이', '바닥에', '과몰입이라', '정신차릴꺼라', '있더라고요', '안시켜주면', '가지려면', '흘려들은적이', '해줘야하니까요', '강다니엘', '인기도', '하기루요첫째', '들은', '발라도', '상대방', '끼쳐', '아이한테', '잡채', '못믿을것',  ...

# %%
from kiwipiepy import Kiwi, Option

kiwi = Kiwi()

Kiwi(
    num_workers=0, 
    model_path=None, 
    load_default_dict=True, 
    integrate_allomorph=True
)

inputs = wordlist

kiwi.extract_words(inputs, min_cnt=1, max_word_len=10, min_score=0.25, pos_score=-3.0, lm_filter=True)
# Out:
# [('부모님', 1.5951398611068726, 86, -0.7513513565063477),
#  ('시부모님', 0.6396675705909729, 22, -0.4865383505821228),
#  ('서이것저것', 0.6229373812675476, 6, -1.3246546983718872),
#  ('애견동반', 0.6011443138122559, 8, -1.9989718198776245),
#  ('재난지원금', 0.5066719651222229, 6, -2.988631248474121),
#  ('엔시티', 0.4403059780597687, 9, -2.824829339981079),
#  ('일반칼국수', 0.41616111993789673, 9, -1.920362949371338),
#  ('투바투', 0.3939288854598999, 7, -2.1660144329071045),
#  ('스타일리스트', 0.3828323781490326, 5, -0.03425504267215729),
#  ('가스라이팅', 0.37034255266189575, 7, -1.4234473705291748),
#  ('요남편', 0.33296629786491394, 37, -1.3809949159622192),
#  ('스트릿우먼파이터', 0.31777065992355347, 3, -2.6770336627960205),
#  ('선생님', 0.30616793036460876, 16, -0.2404392510652542),
#  ('니다남편', 0.2872423827648163, 16, -2.3050408363342285),
#  ('응원법', 0.27162525057792664, 8, -1.5448956489562988),
#  ('스우파', 0.2559112012386322, 10, -2.0608885288238525)]

# %%
kiwi.load_user_dictionary('new.txt')
# Out:
# 25

# %%
kiwi.extract_words(inputs, min_cnt=1, max_word_len=10, min_score=0.25, pos_score=-3.0, lm_filter=True)
# Out:
# [('재난지원금', 0.5066719651222229, 6, -2.988631248474121),
#  ('엔시티', 0.4403059780597687, 9, -2.824829339981079),
#  ('투바투', 0.3939288854598999, 7, -2.1660144329071045),
#  ('스트릿우먼파이터', 0.31777065992355347, 3, -2.6770336627960205),
#  ('스우파', 0.2559112012386322, 10, -2.0608885288238525)]
